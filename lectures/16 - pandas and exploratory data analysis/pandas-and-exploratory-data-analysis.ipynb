# %% [markdown]
# # Pandas data frames (i.e. tables)
#
# https://pandas.pydata.org/
#
# `conda install pandas`

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ![Data_Cortex_Nuclear](images/mice-protein-expression.png)
#
# https://www.kaggle.com/ruslankl/mice-protein-expression/version/1

# %% [markdown]
# Data_Cortex_Nuclear.csv
#
# ![Data_Cortex_Nuclear Excel](images/mice-protein-expression-csv.png)

# %% [markdown]
# ### Spreadsheet --> Pandas DataFrame

# %%
df = pd.read_csv("Data_Cortex_Nuclear.csv")

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df  # preview the data
# Out:
#        MouseID  DYRK1A_N   ITSN1_N    BDNF_N     NR1_N    NR2A_N    pAKT_N  \
# 0        309_1  0.503644  0.747193  0.430175  2.816329  5.990152  0.218830
# 1        309_2  0.514617  0.689064  0.411770  2.789514  5.685038  0.211636
# 2        309_3  0.509183  0.730247  0.418309  2.687201  5.622059  0.209011
# 3        309_4  0.442107  0.617076  0.358626  2.466947  4.979503  0.222886
# 4        309_5  0.434940  0.617430  0.358802  2.365785  4.718679  0.213106
# ...        ...       ...       ...       ...       ...       ...       ...
# 1075  J3295_11  0.254860  0.463591  0.254860  2.092082  2.600035  0.211736
# 1076  J3295_12  0.272198  0.474163  0.251638  2.161390  2.801492  0.251274
# 1077  J3295_13  0.228700  0.395179  0.234118  1.733184  2.220852  0.220665
# 1078  J3295_14  0.221242  0.412894  0.243974  1.876347  2.384088  0.208897
# 1079  J3295_15  0.302626  0.461059  0.256564  2.092790  2.594348  0.251001
#
# ...

# %% [markdown]
# ### Basic info

# %%
df.shape  # just like numpy
# Out:
# (1080, 82)

# %%
df.columns
# Out:
# Index(['MouseID', 'DYRK1A_N', 'ITSN1_N', 'BDNF_N', 'NR1_N', 'NR2A_N', 'pAKT_N',
#        'pBRAF_N', 'pCAMKII_N', 'pCREB_N', 'pELK_N', 'pERK_N', 'pJNK_N',
#        'PKCA_N', 'pMEK_N', 'pNR1_N', 'pNR2A_N', 'pNR2B_N', 'pPKCAB_N',
#        'pRSK_N', 'AKT_N', 'BRAF_N', 'CAMKII_N', 'CREB_N', 'ELK_N', 'ERK_N',
#        'GSK3B_N', 'JNK_N', 'MEK_N', 'TRKA_N', 'RSK_N', 'APP_N', 'Bcatenin_N',
#        'SOD1_N', 'MTOR_N', 'P38_N', 'pMTOR_N', 'DSCR1_N', 'AMPKA_N', 'NR2B_N',
#        'pNUMB_N', 'RAPTOR_N', 'TIAM1_N', 'pP70S6_N', 'NUMB_N', 'P70S6_N',
#        'pGSK3B_N', 'pPKCG_N', 'CDK5_N', 'S6_N', 'ADARB1_N', 'AcetylH3K9_N',
#        'RRP1_N', 'BAX_N', 'ARC_N', 'ERBB4_N', 'nNOS_N', 'Tau_N', 'GFAP_N',
#        'GluR3_N', 'GluR4_N', 'IL1B_N', 'P3525_N', 'pCASP9_N', 'PSD95_N',
#        'SNCA_N', 'Ubiquitin_N', 'pGSK3B_Tyr216_N', 'SHH_N', 'BAD_N', 'BCL2_N',
#        'pS6_N', 'pCFOS_N', 'SYP_N', 'H3AcK18_N', 'EGR1_N', 'H3MeK4_N',
#        'CaNA_N', 'Genotype', 'Treatment', 'Behavior', 'class'],
# ...

# %%
# see all the columns, their data types, and any missing data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MouseID          1080 non-null   object
#  1   DYRK1A_N         1077 non-null   float64
#  2   ITSN1_N          1077 non-null   float64
#  3   BDNF_N           1077 non-null   float64
#  4   NR1_N            1077 non-null   float64
#  5   NR2A_N           1077 non-null   float64
#  6   pAKT_N           1077 non-null   float64
#  7   pBRAF_N          1077 non-null   float64
#  8   pCAMKII_N        1077 non-null   float64
#  9   pCREB_N          1077 non-null   float64
#  10  pELK_N           1077 non-null   float64
#  11  pERK_N           1077 non-null   float64
#  12  pJNK_N           1077 non-null   float64
#  13  PKCA_N           1077 non-null   float64
#  14  pMEK_N           1077 non-null   float64
#  15  pNR1_N           1077 non-null   float64
# ...

# %% [markdown]
# ### Some statistics for each column

# %%
df.describe()
# Out:
#           DYRK1A_N      ITSN1_N       BDNF_N        NR1_N       NR2A_N  \
# count  1077.000000  1077.000000  1077.000000  1077.000000  1077.000000
# mean      0.425810     0.617102     0.319088     2.297269     3.843934
# std       0.249362     0.251640     0.049383     0.347293     0.933100
# min       0.145327     0.245359     0.115181     1.330831     1.737540
# 25%       0.288121     0.473361     0.287444     2.057411     3.155678
# 50%       0.366378     0.565782     0.316564     2.296546     3.760855
# 75%       0.487711     0.698032     0.348197     2.528481     4.440011
# max       2.516367     2.602662     0.497160     3.757641     8.482553
#
#             pAKT_N      pBRAF_N    pCAMKII_N      pCREB_N       pELK_N  ...  \
# count  1077.000000  1077.000000  1077.000000  1077.000000  1077.000000  ...
# mean      0.233168     0.181846     3.537109     0.212574     1.428682  ...
# std       0.041634     0.027042     1.295169     0.032587     0.466904  ...
# ...

# %% [markdown]
# ### Let's get rid of all the `_N` in the column titles to make things easier to look at.

# %%
coltitles = list(df.columns)
for i in range(len(coltitles)):
    if coltitles[i].endswith('_N'):
        coltitles[i] = coltitles[i][:-2]
df.columns = coltitles
df
# Out:
#        MouseID    DYRK1A     ITSN1      BDNF       NR1      NR2A      pAKT  \
# 0        309_1  0.503644  0.747193  0.430175  2.816329  5.990152  0.218830
# 1        309_2  0.514617  0.689064  0.411770  2.789514  5.685038  0.211636
# 2        309_3  0.509183  0.730247  0.418309  2.687201  5.622059  0.209011
# 3        309_4  0.442107  0.617076  0.358626  2.466947  4.979503  0.222886
# 4        309_5  0.434940  0.617430  0.358802  2.365785  4.718679  0.213106
# ...        ...       ...       ...       ...       ...       ...       ...
# 1075  J3295_11  0.254860  0.463591  0.254860  2.092082  2.600035  0.211736
# 1076  J3295_12  0.272198  0.474163  0.251638  2.161390  2.801492  0.251274
# 1077  J3295_13  0.228700  0.395179  0.234118  1.733184  2.220852  0.220665
# 1078  J3295_14  0.221242  0.412894  0.243974  1.876347  2.384088  0.208897
# 1079  J3295_15  0.302626  0.461059  0.256564  2.092790  2.594348  0.251001
#
# ...

# %% [markdown]
# ### Get specific columns & rows

# %%
# get a specific column
df['Genotype']
# Out:
# 0       Control
# 1       Control
# 2       Control
# 3       Control
# 4       Control
#          ...
# 1075     Ts65Dn
# 1076     Ts65Dn
# 1077     Ts65Dn
# 1078     Ts65Dn
# 1079     Ts65Dn
# Name: Genotype, Length: 1080, dtype: object

# %%
type(df), type(df['Genotype'])
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
# index/slice into the rows of the column
df['Genotype'][3:5]
# Out:
# 3    Control
# 4    Control
# Name: Genotype, dtype: object

# %%
# !!! pandas keeps track of row indexes
df['Genotype'][3:5][4]
# Out:
# 'Control'

# %%
# multiple columns in any order
df[['Genotype', 'BDNF']]
# Out:
#      Genotype      BDNF
# 0     Control  0.430175
# 1     Control  0.411770
# 2     Control  0.418309
# 3     Control  0.358626
# 4     Control  0.358802
# ...       ...       ...
# 1075   Ts65Dn  0.254860
# 1076   Ts65Dn  0.251638
# 1077   Ts65Dn  0.234118
# 1078   Ts65Dn  0.243974
# 1079   Ts65Dn  0.256564
#
# [1080 rows x 2 columns]

# %%
# multiple columns in any order & specified row slice
df[['Genotype', 'BDNF']][1070::3]
# Out:
#      Genotype      BDNF
# 1070   Ts65Dn  0.314915
# 1073   Ts65Dn  0.299645
# 1076   Ts65Dn  0.251638
# 1079   Ts65Dn  0.256564

# %%
# get single column as a dataframe instead of a series
df[['Genotype']]
# Out:
#      Genotype
# 0     Control
# 1     Control
# 2     Control
# 3     Control
# 4     Control
# ...       ...
# 1075   Ts65Dn
# 1076   Ts65Dn
# 1077   Ts65Dn
# 1078   Ts65Dn
# 1079   Ts65Dn
#
# [1080 rows x 1 columns]

# %%
type(df['Genotype']), type(df[['Genotype']])
# Out:
# (pandas.core.series.Series, pandas.core.frame.DataFrame)

# %% [markdown]
# # Exercise
#
# Get the `class` for the mice with indices 2-4.

# %% [markdown]
# # Exercise
#
# Get the `class` and `Treatment` for the mice with indices 2-4.

# %% [markdown]
# ### iloc --> slice like NumPy

# %%
# iloc[rows, columns] --> 2D slice just like numpy
df.iloc[3:9:2, 5:10]
# Out:
#        NR2A      pAKT     pBRAF   pCAMKII     pCREB
# 3  4.979503  0.222886  0.176463  2.152301  0.207004
# 5  4.807635  0.218578  0.176233  2.141282  0.195188
# 7  4.268735  0.214834  0.179668  2.007985  0.189803

# %% [markdown]
# ### loc --> slice by name

# %%
# loc[rows, columns]
df.loc[1077:1079, 'Genotype':'class']
# Out:
#      Genotype Treatment Behavior   class
# 1077   Ts65Dn    Saline      S/C  t-SC-s
# 1078   Ts65Dn    Saline      S/C  t-SC-s
# 1079   Ts65Dn    Saline      S/C  t-SC-s

# %% [markdown]
# # Exercise
#
# Use `loc` to get the `class` and `Treatment` for the mice with indices 2-4.

# %% [markdown]
# ### Select rows with a logical array

# %%
hasDownSyndrome = (df['Genotype'] == 'Ts65Dn')

hasDownSyndrome
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1075     True
# 1076     True
# 1077     True
# 1078     True
# 1079     True
# Name: Genotype, Length: 1080, dtype: bool

# %%
# only rows fow down syndrome mice
df[hasDownSyndrome]
# Out:
#        MouseID    DYRK1A     ITSN1      BDNF       NR1      NR2A      pAKT  \
# 570     3414_1  0.838053  1.006324  0.364953  2.603061  4.207680  0.202548
# 571     3414_2  0.938245  1.077099  0.366149  2.703612  4.484228  0.197465
# 572     3414_3  0.956488  1.108441  0.384049  2.662564  4.606357  0.203799
# 573     3414_4  0.731738  0.944241  0.324365  2.320243  3.621250  0.198649
# 574     3414_5  0.815503  1.005562  0.335976  2.379290  3.641657  0.217870
# ...        ...       ...       ...       ...       ...       ...       ...
# 1075  J3295_11  0.254860  0.463591  0.254860  2.092082  2.600035  0.211736
# 1076  J3295_12  0.272198  0.474163  0.251638  2.161390  2.801492  0.251274
# 1077  J3295_13  0.228700  0.395179  0.234118  1.733184  2.220852  0.220665
# 1078  J3295_14  0.221242  0.412894  0.243974  1.876347  2.384088  0.208897
# 1079  J3295_15  0.302626  0.461059  0.256564  2.092790  2.594348  0.251001
#
# ...

# %%
# only rows for down syndrome mice that recieved saline treatment
gotSaline = df['Treatment'] == 'Saline'
sel = hasDownSyndrome & gotSaline
df[sel]
# Out:
#        MouseID    DYRK1A     ITSN1      BDNF       NR1      NR2A      pAKT  \
# 840    18899_1  0.506200  0.696046  0.316019  2.204591  4.154323  0.254859
# 841    18899_2  0.523760  0.746212  0.324897  2.285640  4.322314  0.268767
# 842    18899_3  0.518612  0.733233  0.356137  2.330148  4.631455  0.272468
# 843    18899_4  0.436986  0.626614  0.295108  2.008023  3.605088  0.258317
# 844    18899_5  0.505599  0.719826  0.314600  2.194110  3.908544  0.281833
# ...        ...       ...       ...       ...       ...       ...       ...
# 1075  J3295_11  0.254860  0.463591  0.254860  2.092082  2.600035  0.211736
# 1076  J3295_12  0.272198  0.474163  0.251638  2.161390  2.801492  0.251274
# 1077  J3295_13  0.228700  0.395179  0.234118  1.733184  2.220852  0.220665
# 1078  J3295_14  0.221242  0.412894  0.243974  1.876347  2.384088  0.208897
# 1079  J3295_15  0.302626  0.461059  0.256564  2.092790  2.594348  0.251001
#
# ...

# %%
# MouseID and pCFOS levels for only down syndrome mice that recieved saline treatment
df[sel][['MouseID', 'pCFOS']]
# Out:
#        MouseID     pCFOS
# 840    18899_1       NaN
# 841    18899_2       NaN
# 842    18899_3       NaN
# 843    18899_4       NaN
# 844    18899_5       NaN
# ...        ...       ...
# 1075  J3295_11  0.183324
# 1076  J3295_12  0.175674
# 1077  J3295_13  0.158296
# 1078  J3295_14  0.196296
# 1079  J3295_15  0.187556
#
# [240 rows x 2 columns]

# %% [markdown]
# ### Missing values

# %%
# MouseID and pCFOS levels for only down syndrome mice that recieved saline treatment
# Get rid of any mice missing pCFOS data
df[sel][['MouseID', 'pCFOS']].dropna()
# Out:
#        MouseID     pCFOS
# 855     3476_1  0.109931
# 856     3476_2  0.123052
# 857     3476_3  0.114269
# 858     3476_4  0.111655
# 859     3476_5  0.123541
# ...        ...       ...
# 1075  J3295_11  0.183324
# 1076  J3295_12  0.175674
# 1077  J3295_13  0.158296
# 1078  J3295_14  0.196296
# 1079  J3295_15  0.187556
#
# [210 rows x 2 columns]

# %% [markdown]
# # Exercise
#
# Get the `MouseID` for all mice missing `pCFOS` measurements.

# %% [markdown]
# ### Add columns

# %%
df['HasDownSyndrome'] = hasDownSyndrome

df
# Out:
#        MouseID    DYRK1A     ITSN1      BDNF       NR1      NR2A      pAKT  \
# 0        309_1  0.503644  0.747193  0.430175  2.816329  5.990152  0.218830
# 1        309_2  0.514617  0.689064  0.411770  2.789514  5.685038  0.211636
# 2        309_3  0.509183  0.730247  0.418309  2.687201  5.622059  0.209011
# 3        309_4  0.442107  0.617076  0.358626  2.466947  4.979503  0.222886
# 4        309_5  0.434940  0.617430  0.358802  2.365785  4.718679  0.213106
# ...        ...       ...       ...       ...       ...       ...       ...
# 1075  J3295_11  0.254860  0.463591  0.254860  2.092082  2.600035  0.211736
# 1076  J3295_12  0.272198  0.474163  0.251638  2.161390  2.801492  0.251274
# 1077  J3295_13  0.228700  0.395179  0.234118  1.733184  2.220852  0.220665
# 1078  J3295_14  0.221242  0.412894  0.243974  1.876347  2.384088  0.208897
# 1079  J3295_15  0.302626  0.461059  0.256564  2.092790  2.594348  0.251001
#
# ...

# %% [markdown]
# ### Remove columns

# %%
del df['HasDownSyndrome']

df
# Out:
#        MouseID    DYRK1A     ITSN1      BDNF       NR1      NR2A      pAKT  \
# 0        309_1  0.503644  0.747193  0.430175  2.816329  5.990152  0.218830
# 1        309_2  0.514617  0.689064  0.411770  2.789514  5.685038  0.211636
# 2        309_3  0.509183  0.730247  0.418309  2.687201  5.622059  0.209011
# 3        309_4  0.442107  0.617076  0.358626  2.466947  4.979503  0.222886
# 4        309_5  0.434940  0.617430  0.358802  2.365785  4.718679  0.213106
# ...        ...       ...       ...       ...       ...       ...       ...
# 1075  J3295_11  0.254860  0.463591  0.254860  2.092082  2.600035  0.211736
# 1076  J3295_12  0.272198  0.474163  0.251638  2.161390  2.801492  0.251274
# 1077  J3295_13  0.228700  0.395179  0.234118  1.733184  2.220852  0.220665
# 1078  J3295_14  0.221242  0.412894  0.243974  1.876347  2.384088  0.208897
# 1079  J3295_15  0.302626  0.461059  0.256564  2.092790  2.594348  0.251001
#
# ...

# %% [markdown]
# ### Visualize columns

# %%
df['pCFOS'].plot()

# plots use matplotlib
plt.xlabel('Index')
plt.ylabel('pCFOS')
plt.title('pCFOS column data');

# %%
df[['pCREB', 'pCFOS']].plot(xlabel='Mouse', ylabel='Expression');

plt.title('Each trace is a column in the dataframe');

# %% [markdown]
# ### Missing values

# %%
df.dropna()  # remove all rows with one or more missing values
# Out:
#       MouseID    DYRK1A     ITSN1      BDNF       NR1      NR2A      pAKT  \
# 75     3415_1  0.649781  0.828696  0.405862  2.921435  5.167979  0.207174
# 76     3415_2  0.616481  0.841974  0.388584  2.862575  5.194163  0.223433
# 77     3415_3  0.637424  0.852882  0.400561  2.968155  5.350820  0.208790
# 78     3415_4  0.576815  0.755390  0.348346  2.624901  4.727509  0.205892
# 79     3415_5  0.542545  0.757917  0.350051  2.634509  4.735602  0.210526
# ...       ...       ...       ...       ...       ...       ...       ...
# 1045  3525_11  0.382149  0.595792  0.399101  2.527574  4.629493  0.317810
# 1046  3525_12  0.387947  0.586510  0.431650  2.527041  4.781082  0.316903
# 1047  3525_13  0.343695  0.562547  0.361243  2.412885  3.949361  0.330158
# 1048  3525_14  0.346594  0.551467  0.390353  2.445052  4.236201  0.343610
# 1049  3525_15  0.365907  0.552861  0.386275  2.473812  4.347236  0.353783
#
#          pBRAF   pCAMKII     pCREB  ...     pCFOS       SYP   H3AcK18  \
# ...

# %%
df.fillna(0)  # set all missing values to 0
# Out:
#        MouseID    DYRK1A     ITSN1      BDNF       NR1      NR2A      pAKT  \
# 0        309_1  0.503644  0.747193  0.430175  2.816329  5.990152  0.218830
# 1        309_2  0.514617  0.689064  0.411770  2.789514  5.685038  0.211636
# 2        309_3  0.509183  0.730247  0.418309  2.687201  5.622059  0.209011
# 3        309_4  0.442107  0.617076  0.358626  2.466947  4.979503  0.222886
# 4        309_5  0.434940  0.617430  0.358802  2.365785  4.718679  0.213106
# ...        ...       ...       ...       ...       ...       ...       ...
# 1075  J3295_11  0.254860  0.463591  0.254860  2.092082  2.600035  0.211736
# 1076  J3295_12  0.272198  0.474163  0.251638  2.161390  2.801492  0.251274
# 1077  J3295_13  0.228700  0.395179  0.234118  1.733184  2.220852  0.220665
# 1078  J3295_14  0.221242  0.412894  0.243974  1.876347  2.384088  0.208897
# 1079  J3295_15  0.302626  0.461059  0.256564  2.092790  2.594348  0.251001
#
# ...

# %% [markdown]
# ### Number of missing values in each column

# %%
df.isnull().sum()
# Out:
# MouseID      0
# DYRK1A       3
# ITSN1        3
# BDNF         3
# NR1          3
#             ..
# CaNA         0
# Genotype     0
# Treatment    0
# Behavior     0
# class        0
# Length: 82, dtype: int64

# %%
df.isnull().sum().plot(figsize=(10,3), rot=90);

# %%
# bar plot
df.isnull().sum().plot.bar(figsize=(10,3));

# %% [markdown]
# You might think about not using the handful of features with a lot of missing values for your analysis.

# %% [markdown]
# # Exerecise
#
# Remove the column with the most missing values.

# %% [markdown]
# ### Group rows & compute something for each group
#
# Also see `pivot_table`

# %%
df.groupby('Genotype')

# %%
df.groupby('Genotype').mean()
# Out:
#             DYRK1A     ITSN1      BDNF       NR1      NR2A      pAKT  \
# Genotype
# Control   0.404756  0.575927  0.321132  2.333654  3.984687  0.229578
# Ts65Dn    0.449480  0.663394  0.316791  2.256362  3.685690  0.237204
#
#              pBRAF   pCAMKII     pCREB      pELK  ...       SHH       BAD  \
# Genotype                                          ...
# Control   0.181515  3.505182  0.207285  1.443155  ...  0.226943  0.157057
# Ts65Dn    0.182220  3.573004  0.218520  1.412411  ...  0.226378  0.158766
#
#               BCL2       pS6     pCFOS       SYP   H3AcK18      EGR1  \
# Genotype
# Control   0.135478  0.123365  0.132923  0.460376  0.156779  0.189647
# Ts65Dn    0.134017  0.119460  0.128882  0.430088  0.183324  0.176156
#
#             H3MeK4      CaNA
# Genotype
# Control   0.198516  1.324037
# Ts65Dn    0.211409  1.353148
#
# [2 rows x 77 columns]

# %%
# plot defaults to plotting each column as a line
df.groupby('Genotype').mean().plot(legend=None);

# %%
df.groupby('Genotype').mean().T
# Out:
# Genotype   Control    Ts65Dn
# DYRK1A    0.404756  0.449480
# ITSN1     0.575927  0.663394
# BDNF      0.321132  0.316791
# NR1       2.333654  2.256362
# NR2A      3.984687  3.685690
# ...            ...       ...
# SYP       0.460376  0.430088
# H3AcK18   0.156779  0.183324
# EGR1      0.189647  0.176156
# H3MeK4    0.198516  0.211409
# CaNA      1.324037  1.353148
#
# [77 rows x 2 columns]

# %%
df.groupby('Genotype').mean().T.plot(figsize=(10,3), rot=90);

# %%
df.groupby('Genotype').mean().T.plot.bar(figsize=(10,3), rot=90);

# %% [markdown]
# ### Nested groups

# %%
df.groupby(['Genotype', 'Treatment']).sum()
# Out:
#                         DYRK1A       ITSN1       BDNF         NR1  \
# Genotype Treatment
# Control  Memantine  113.048904  163.342224  94.524479  679.107326
#          Saline     117.662182  164.936101  88.520562  651.075739
# Ts65Dn   Memantine  128.135872  184.111650  85.562397  617.758208
#          Saline      99.750587  152.228856  75.050752  526.217556
#
#                            NR2A       pAKT      pBRAF      pCAMKII      pCREB  \
# Genotype Treatment
# Control  Memantine  1165.193447  70.677721  55.763691  1147.877081  60.994917
#          Saline     1106.078423  60.181752  47.699587   850.076614  57.157384
# Ts65Dn   Memantine  1028.994680  65.171495  50.619970   998.872821  58.749817
#          Saline      839.650309  55.091079  41.765377   812.639988  52.040005
#
#                           pELK  ...        SHH        BAD       BCL2  \
# Genotype Treatment              ...
# Control  Memantine  415.632666  ...  67.707033  36.093774  27.603222
# ...

# %%
df.groupby(['Genotype', 'Treatment']).sum().T.plot(figsize=(10,3), rot=90);

# %% [markdown]
# ### Sort rows

# %%
df.sort_values(by='BDNF')[['MouseID', 'Genotype', 'BDNF']]
# Out:
#      MouseID Genotype      BDNF
# 181   3413_2  Control  0.115181
# 192  3413_13  Control  0.185980
# 974  3425_15   Ts65Dn  0.194160
# 193  3413_14  Control  0.197271
# 190  3413_11  Control  0.198159
# ..       ...      ...       ...
# 32     320_3  Control  0.470056
# 375   3497_1  Control  0.497160
# 987  3426_13   Ts65Dn       NaN
# 988  3426_14   Ts65Dn       NaN
# 989  3426_15   Ts65Dn       NaN
#
# [1080 rows x 3 columns]

# %%
# One reason why it is beneficial to attach indexes to each row
# irrespective of their order is it's easy to keep track of
# specific subjects no matter how we rearrange the data.
df.sort_values(by='BDNF')['MouseID'][974]
# Out:
# '3425_15'

# %% [markdown]
# ### Changing the original DataFrame
#
# Everything we've done so far has not altered the original DataFrame.
#
# But what if we want to alter it?
#
# * *Option 1:* Assign a `copy` of whatever we did to a `new DataFrame`.
# * *Option 2:* Edit the original DataFrame directily by telling Pandas to perform actions `inplace`.

# %%
# df2 is a copy of the sorted df, df is unchanged
df2 = df.sort_values(by='BDNF')

# %%
# df2 is itself resorted
df2.sort_values(by='pCFOS', inplace=True)

# %% [markdown]
# ### Editing the data frame
#
# Most column manipulations work just like NumPy arrays.

# %%
df2['ITSN1'] = df2['DYRK1A'] * 100
df2['BDNF'] = 8

df2[['DYRK1A', 'ITSN1', 'BDNF']]
# Out:
#        DYRK1A      ITSN1  BDNF
# 149  0.472849  47.284879     8
# 887  0.880699  88.069855     8
# 272  0.376922  37.692195     8
# 885  0.787914  78.791400     8
# 140  0.633407  63.340684     8
# ..        ...        ...   ...
# 50   0.457992  45.799236     8
# 21   0.702608  70.260829     8
# 46   0.516108  51.610811     8
# 45   0.560614  56.061437     8
# 47   0.507321  50.732128     8
#
# [1080 rows x 3 columns]

# %%
df2['BDNF'][140] = 100

df2[['BDNF']]
# Out:
# /var/folders/k1/swt2sp1x6mj7wyc2cs76qq4m0000gn/T/ipykernel_14158/1476813621.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['BDNF'][140] = 100
#      BDNF
# 149     8
# 887     8
# 272     8
# 885     8
# 140   100
# ..    ...
# 50      8
# 21      8
# 46      8
# 45      8
# 47      8
#
# [1080 rows x 1 columns]

# %%
df2.loc[50:21, 'BDNF'] = 500

df2[['BDNF']]
# Out:
#      BDNF
# 149     8
# 887     8
# 272     8
# 885     8
# 140   100
# ..    ...
# 50    500
# 21    500
# 46      8
# 45      8
# 47      8
#
# [1080 rows x 1 columns]

# %% [markdown]
# ### NumPy --> Pandas

# %%
import numpy as np

a = np.random.random((3,4))
a
# Out:
# array([[0.04594459, 0.95753666, 0.59118653, 0.25882539],
#        [0.87305461, 0.64853201, 0.51950764, 0.93920678],
#        [0.09383623, 0.06797712, 0.12428213, 0.68859724]])

# %%
af = pd.DataFrame(a)
af
# Out:
#           0         1         2         3
# 0  0.045945  0.957537  0.591187  0.258825
# 1  0.873055  0.648532  0.519508  0.939207
# 2  0.093836  0.067977  0.124282  0.688597

# %%
af.columns = ['A', 'B', 'C', 'D']
af
# Out:
#           A         B         C         D
# 0  0.045945  0.957537  0.591187  0.258825
# 1  0.873055  0.648532  0.519508  0.939207
# 2  0.093836  0.067977  0.124282  0.688597

# %% [markdown]
# ### Pandas --> NumPy

# %%
af
# Out:
#           A         B         C         D
# 0  0.045945  0.957537  0.591187  0.258825
# 1  0.873055  0.648532  0.519508  0.939207
# 2  0.093836  0.067977  0.124282  0.688597

# %%
af.to_numpy()
# Out:
# array([[0.04594459, 0.95753666, 0.59118653, 0.25882539],
#        [0.87305461, 0.64853201, 0.51950764, 0.93920678],
#        [0.09383623, 0.06797712, 0.12428213, 0.68859724]])

# %% [markdown]
# # Exercise
#
# Get the `BDNF` and `ITSN1` columns for the original dataframe `df` as a $N \times 2$ NumPy array.

# %% [markdown]
# # Seaborn
#
# https://seaborn.pydata.org/
#
# `conda install seaborn`

# %%
import seaborn as sns

# %%
sns.relplot(x="BDNF", y="pCAMKII", data=df);

# %%
sns.catplot(x="Genotype", y="pCAMKII", data=df);

# %%
sns.catplot(x="Genotype", y="pCAMKII", kind="box", data=df);

# %%
sns.catplot(x="Genotype", y="pCAMKII", hue="Treatment", kind="box", data=df);

# %%
sns.catplot(x="Genotype", y="pCAMKII", hue="Treatment", col="Behavior", kind="box", data=df);

# %%
sns.catplot(x="Genotype", y="pCAMKII", hue="Treatment", col="Behavior", kind="swarm", data=df);

# %%
sns.catplot(x="Genotype", y="pCAMKII", row="Treatment", col="Behavior", kind="swarm", data=df);

# %% [markdown]
# # Exercise
#
# Plot box plots comparing `BDDNF` expression levels for each behavior pardigm under each treatment protocol.

# %%
sns.pairplot(df.loc[:,'NR2A':'pCAMKII']);

# %% [markdown]
# ### Correlations amongst columns
#
# ![correlation](images/correlation.png)

# %%
df.corr()
# Out:
#            DYRK1A     ITSN1      BDNF       NR1      NR2A      pAKT     pBRAF  \
# DYRK1A   1.000000  0.959512  0.359433  0.294526  0.325063 -0.180959 -0.093737
# ITSN1    0.959512  1.000000  0.459884  0.422492  0.426182 -0.147775 -0.076507
# BDNF     0.359433  0.459884  1.000000  0.805784  0.749993  0.317537  0.390530
# NR1      0.294526  0.422492  0.805784  1.000000  0.873889  0.211540  0.244224
# NR2A     0.325063  0.426182  0.749993  0.873889  1.000000  0.110172  0.111143
# ...           ...       ...       ...       ...       ...       ...       ...
# SYP     -0.047246  0.042422  0.450433  0.473366  0.400526  0.248531  0.284492
# H3AcK18 -0.384816 -0.347339 -0.135637 -0.234171 -0.314210  0.338456  0.301049
# EGR1    -0.323397 -0.399856 -0.239907 -0.319672 -0.346987  0.280476  0.349281
# H3MeK4  -0.473734 -0.511433 -0.244732 -0.351958 -0.454366  0.383404  0.402397
# CaNA     0.476033  0.517782  0.262578  0.205463  0.187292 -0.238567 -0.213691
#
# ...

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr());

# %% [markdown]
# Note that the corr() matrix <font color=red>does NOT contain any categorical variables!</font>

# %% [markdown]
# # heatmapz
#
# https://pypi.org/project/heatmapz/
#
# A better way to visualize correlations

# %%
# see heatmap.py module file
from heatmap import heatmap, corrplot

# %%
plt.figure(figsize=(15,15))
ax = corrplot(df.corr(), size_scale=50)
ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation=90, ha='center');

# %% [markdown]
# # Dython
#
# https://github.com/shakedzy/dython
#
# `conda install -c conda-forge dython`
#
# ### Correlations between both numerical AND categorical data!

# %%
import dython

# %%
result = dython.nominal.associations(df.iloc[:,1:], compute_only=True)  # ignore MouseID column
corr = result['corr']

corr
# Out:
#              DYRK1A     ITSN1      BDNF       NR1      NR2A      pAKT  \
# DYRK1A     1.000000  0.959255  0.367778  0.306508  0.335411 -0.147453
# ITSN1      0.959255  1.000000  0.473075  0.437863  0.440253 -0.104235
# BDNF       0.367778  0.473075  1.000000  0.826391  0.762199  0.379601
# NR1        0.306508  0.437863  0.826391  1.000000  0.876241  0.284832
# NR2A       0.335411  0.440253  0.762199  0.876241  1.000000  0.163371
# ...             ...       ...       ...       ...       ...       ...
# CaNA       0.472178  0.510772  0.241898  0.187222  0.178642 -0.234543
# Genotype   0.084061  0.164719  0.059476  0.123151  0.167971  0.071788
# Treatment  0.006329  0.024292  0.045885  0.045167  0.017966  0.141788
# Behavior   0.507845  0.485934  0.154089  0.034652  0.120696  0.322728
# class      0.538328  0.535317  0.310029  0.298001  0.358313  0.409956
#
#               pBRAF   pCAMKII     pCREB      pELK  ...     pCFOS       SYP  \
# ...

# %%
plt.figure(figsize=(15,15))
ax = corrplot(corr, size_scale=50)
ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation=90, ha='center');

# %% [markdown]
# # Exercise
#
# Which protein is most correlated with `class`?
#
# Plot categorical jitter plots comparing the expression level of this protein for each `class`.

# %% [markdown]
# # Sweetviz
#
# https://pypi.org/project/sweetviz/
#
# `conda install -c conda-forge sweetviz`

# %%
import sweetviz as sv

# %%
report = sv.analyze(df)
report.show_html("sweetviz_report.html")
# Out:
#                                              |                                                       | [  0%] …
# Report sweetviz_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ### Let's examine the correlation between `SOD1` and `class`.

# %%
sns.catplot(x="class", y="SOD1", data=df);

# %% [markdown]
# ### From the above plot, it is clear that `SOD1` primarily differs based on the `Behavior` conditioning paradigm.

# %%
sns.catplot(x="Behavior", y="SOD1", hue="Genotype", data=df);

# %% [markdown]
# # Mito
#
# https://docs.trymito.io/
#
# `pip install mitoinstaller`
#
# `python -m mitoinstaller install`

# %%
import mitosheet

# %%
mitosheet.sheet(df)
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-ddd186d4-092c-427e-9f21-a52ec9383350", "code": {"imports…
